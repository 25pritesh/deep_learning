# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.model_selection import KFold
from keras import optimizers
from sklearn import model_selection
# %matplotlib inline

# %%
df_dia = pd.read_csv(r"C:\Users\Odh05\Desktop\Ai_training\diabetes.csv")
df_dia.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_dia.columns = ['pregnan','glucose','bp','skin','insulin','bmi','pedigree','age','class']

# %%
X = df_dia.iloc[:,0:8]
print(X)
Y = df_dia['class']
print(Y)
# Out:
#      pregnan  glucose  bp  skin  insulin   bmi  pedigree  age
# 0          6      148  72    35        0  33.6     0.627   50
# 1          1       85  66    29        0  26.6     0.351   31
# 2          8      183  64     0        0  23.3     0.672   32
# 3          1       89  66    23       94  28.1     0.167   21
# 4          0      137  40    35      168  43.1     2.288   33
# 5          5      116  74     0        0  25.6     0.201   30
# 6          3       78  50    32       88  31.0     0.248   26
# 7         10      115   0     0        0  35.3     0.134   29
# 8          2      197  70    45      543  30.5     0.158   53
# 9          8      125  96     0        0   0.0     0.232   54
# 10         4      110  92     0        0  37.6     0.191   30
# 11        10      168  74     0        0  38.0     0.537   34
# 12        10      139  80     0        0  27.1     1.441   57
# 13         1      189  60    23      846  30.1     0.398   59
# ...

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(X,Y,test_size=0.25,random_state=0)
# [X_train, x_test, y_train, y_test] = \ train_test_split(X,Y, test_size=0.3, random_state=99)

# %%
#define architecture
#define model architecture 3 layers
model_dia  = Sequential()
model_dia.add(Dense(4, activation='relu',input_dim=8))#input layer
model_dia.add(Dense(6, activation='relu'))#hidden layer
model_dia.add(Dense(1, activation='sigmoid'))#output layer
model_dia.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_19 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_20 (Dense)             (None, 6)                 30
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 7
# ...
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile the model
model_dia.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_diag = model_dia.fit(x_train,y_train,batch_size=10,epochs=250,verbose=0)

# %%
model_epoc_values = model_diag.history['acc']
plt.plot(model_epoc_values)
plt.show()
